# %% [markdown]
# # Example
# This example follows the Section 3.2 Single load-unload cycle example from [1]. It will perofm the fits using the Partial Curve Mapping method, the Area between two curves methods, the Discrete Fréchet Distance, and the Curve Length based similarity function.
#
#
#
# # Fit without noise
# Essentially we want to find the beta paramters that produce the following curve. We'll use a global optimization algorithim (DE from SciPy [2], [3], [4]) to do so. This is regression of a single load-unload cycle.
#
#
# ### References
# [1] Jekel, C. F., Venter, G., Venter, M. P., Stander, N., & Haftka, R. T. (2018). Similarity measures for identifying material parameters from hysteresis loops using inverse analysis. International Journal of Material Forming. https://doi.org/10.1007/s12289-018-1421-8
#
# [2] Storn, R and Price, K, Differential Evolution - a Simple and Efficient Heuristic for Global Optimization over Continuous Spaces, Journal of Global Optimization, 1997, 11, 341 - 359.
#
# [3] http://www1.icsi.berkeley.edu/~storn/code.html
#
# [4] http://en.wikipedia.org/wiki/Differential_evolution

# %%
import numpy as np
import matplotlib.pyplot as plt
import similarity_measures
from scipy.optimize import differential_evolution

x1 = np.linspace(0,1.0,num=100)
xEnd = np.log((1.0 + (2.0*np.exp(1.0)) - np.exp(1.0))/2.0)
x2 = np.linspace(1.0,xEnd, num=50)

y1 = np.exp(x1) - 1.0
y2 = 2*np.exp(x2) - 2.0*np.exp(1.0) + np.exp(1.0) - 1.0
x = np.concatenate((x1,x2))
y = np.concatenate((y1,y2))

exp_data = np.zeros((len(x), 2))
exp_data[:, 0] = x
exp_data[:, 1] = y


plt.figure()
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# # Define a numerical model
# We can define a function that will act as out numerical model. This function will return the x, y values for a certain set of Beta paramters.

# %%
def getXY(betas):
    x1 = np.linspace(0,1.0,num=100)
    xEnd = np.log((1.0 + (2.0*np.exp(1.0)) - np.exp(1.0))/2.0)
    x2 = np.linspace(1.0,xEnd, num=50)

    y1 = np.exp(betas[0]*x1) + betas[1]
    y2 = 2.0*np.exp(betas[2]*x2) -2.0*np.exp(betas[3]) + np.exp(1.0) -1.0
    x = np.concatenate((x1,x2))
    y = np.concatenate((y1,y2))
    return x, y

beta = [1.5, -1.5, 2.0, 2.0]
x, y = getXY(beta)

# plot the results
plt.figure()
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# # Fit using the PCM method

# %%
# define an objective function to minimize
def my_fun(betas):
    x, y = getXY(betas)
    num_data = np.zeros((len(x), 2))
    num_data[:, 0] = x
    num_data[:, 1] = y
    # evaluate the difference between exp_data and num_data using PCM method
    return similarity_measures.pcm(exp_data, num_data)

# set up bounds for the optimization problem
bounds = np.ones((4, 2))*2.0
bounds[0, 0] = 0.0
bounds[1, 0] = -2.0
bounds[1, 0] = 0.0
bounds[2, 0] = 0.0
bounds[3, 0] = 0.0

# USE DE from scipy to do the optimization

res = differential_evolution(my_fun, bounds=bounds, maxiter=1000, popsize=20, tol=0.001)

print(res)

# Compute the resulting x y curve
x, y = getXY(res.x)

# plot the results
plt.figure()
plt.title('Result of optimization')
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()
# Out:
#      fun: 2.719103364712301
#      jac: array([  4.74036757, 218.53007857, 161.08413421, 122.0894994 ])
#  message: 'Optimization terminated successfully.'
#     nfev: 10800
#      nit: 125
#  success: True
#        x: array([5.40500626e-01, 3.82946627e-04, 9.99697184e-01, 1.10278741e+00])

# %% [markdown]
# # Fit with Area between curves measure

# %%
# define an objective function to minimize
def my_fun(betas):
    x, y = getXY(betas)
    num_data = np.zeros((len(x), 2))
    num_data[:, 0] = x
    num_data[:, 1] = y
    # evaluate the difference between exp_data and num_data using Area method
    return similarity_measures.area_between_two_curves(exp_data, num_data)

res = differential_evolution(my_fun, bounds=bounds, maxiter=1000, popsize=30, tol=0.001)

print(res)

# Compute the resulting x y curve
x, y = getXY(res.x)

# plot the results
plt.figure()
plt.title('Result of optimization')
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()
# Out:
#      fun: 3187.8370568148666
#      jac: array([ 4.81395546e-01,  7.87576937e-01,  3.08260219e+03, -5.91171556e-04])
#  message: 'Optimization terminated successfully.'
#     nfev: 1430
#      nit: 10
#  success: True
#        x: array([ 0.99999389, -0.99998655, 10.        ,  8.07633615])

# %% [markdown]
# # Fit with Discrete Fréchet distance

# %%
# define an objective function to minimize
def my_fun(betas):
    x, y = getXY(betas)
    num_data = np.zeros((len(x), 2))
    num_data[:, 0] = x
    num_data[:, 1] = y
    # evaluate the difference between exp_data and num_data using Frechet method
    return similarity_measures.frechet_dist(exp_data, num_data)

# set up bounds for the optimization problem
bounds = np.ones((4, 2))*10.0
bounds[0, 0] = 0.0
bounds[1, 0] = -10.0
bounds[2, 0] = 10.0
bounds[3, 0] = 0.0

# USE DE from scipy to do the optimization
from scipy.optimize import differential_evolution

res = differential_evolution(my_fun, bounds=bounds)

print(res)

# Compute the resulting x y curve
x, y = getXY(res.x)

# plot the results
plt.figure()
plt.title('Result of optimization')
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()
# Out:
#      fun: 21532.293091653482
#      jac: array([    0.        ,     0.        , 44052.93511809, 15728.86030772])
#  message: 'Optimization terminated successfully.'
#     nfev: 920
#      nit: 11
#  success: True
#        x: array([ 3.16348877,  6.801181  , 10.        ,  9.32904025])

# %% [markdown]
# # Fit with Curve Length based similarity function

# %%
# define an objective function to minimize
def my_fun(betas):
    x, y = getXY(betas)
    num_data = np.zeros((len(x), 2))
    num_data[:, 0] = x
    num_data[:, 1] = y    
    # evaluate the difference between exp_data and num_data using curve length method
    return similarity_measures.curve_length_measure(exp_data, num_data)

# set up bounds for the optimization problem
bounds = np.ones((4, 2))*10.0
bounds[0, 0] = 0.0
bounds[1, 0] = -10.0
bounds[2, 0] = 10.0
bounds[3, 0] = 0.0

# USE DE from scipy to do the optimization
from scipy.optimize import differential_evolution

res = differential_evolution(my_fun, bounds=bounds)

print(res)

# Compute the resulting x y curve
x, y = getXY(res.x)

# plot the results
plt.figure()
plt.title('Result of optimization')
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()
# Out:
#      fun: 80.38086618967274
#      jac: array([-0.07862582, -0.04641123,  8.8035307 , -0.01756462])
#  message: 'Optimization terminated successfully.'
#     nfev: 1120
#      nit: 16
#  success: True
#        x: array([ 0.7531296 , -0.94005107, 10.        ,  9.94212659])

# %% [markdown]
# # Fit with noise
# Let's take the same problem, and add artificial noise to the data. Essentially we want to find the beta paramters that produce the following curve. We'll use a global optimization algorithim to do so. This is regression of a single load-unload cycle.

# %%
#   add noise to the data
noise = np.random.normal(mu,var,size=150)
exp_data[:, 1] = noise + exp_data[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0f24c5aa0933> in <module>()
#       1 #   add noise to the data
# ----> 2 noise = np.random.normal(mu,var,size=150)
#       3 exp_data[:, 1] = noise + exp_data[:, 1]
#
# NameError: name 'mu' is not defined

# %% [markdown]
# # Fit using the PCM method

# %%
# define an objective function to minimize
def my_fun(betas):
    x, y = getXY(betas)
    num_data = np.zeros((len(x), 2))
    num_data[:, 0] = x
    num_data[:, 1] = y
    # evaluate the difference between exp_data and num_data using PCM method
    return similarity_measures.pcm(exp_data, num_data)

# set up bounds for the optimization problem
bounds = np.ones((4, 2))*10.0
bounds[0, 0] = 0.0
bounds[1, 0] = -10.0
bounds[2, 0] = 10.0
bounds[3, 0] = 0.0

# USE DE from scipy to do the optimization
from scipy.optimize import differential_evolution

res = differential_evolution(my_fun, bounds=bounds)

print(res)

# Compute the resulting x y curve
x, y = getXY(res.x)

# plot the results
plt.figure()
plt.title('Result of optimization')
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# # Fit with Area between curves measure

# %%
# define an objective function to minimize
def my_fun(betas):
    x, y = getXY(betas)
    num_data = np.zeros((len(x), 2))
    num_data[:, 0] = x
    num_data[:, 1] = y
    # evaluate the difference between exp_data and num_data using Area method
    return similarity_measures.area_between_two_curves(exp_data, num_data)

# set up bounds for the optimization problem
bounds = np.ones((4, 2))*10.0
bounds[0, 0] = 0.0
bounds[1, 0] = -10.0
bounds[2, 0] = 10.0
bounds[3, 0] = 0.0

# USE DE from scipy to do the optimization
from scipy.optimize import differential_evolution

res = differential_evolution(my_fun, bounds=bounds)

print(res)

# Compute the resulting x y curve
x, y = getXY(res.x)

# plot the results
plt.figure()
plt.title('Result of optimization')
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# # Fit with Discrete Fréchet distance

# %%
# define an objective function to minimize
def my_fun(betas):
    x, y = getXY(betas)
    num_data = np.zeros((len(x), 2))
    num_data[:, 0] = x
    num_data[:, 1] = y
    # evaluate the difference between exp_data and num_data using Frechet method
    return similarity_measures.frechet_dist(exp_data, num_data)

# set up bounds for the optimization problem
bounds = np.ones((4, 2))*10.0
bounds[0, 0] = 0.0
bounds[1, 0] = -10.0
bounds[2, 0] = 10.0
bounds[3, 0] = 0.0

# USE DE from scipy to do the optimization
from scipy.optimize import differential_evolution

res = differential_evolution(my_fun, bounds=bounds)

print(res)

# Compute the resulting x y curve
x, y = getXY(res.x)

# plot the results
plt.figure()
plt.title('Result of optimization')
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# # Fit with Curve Length based similarity function

# %%
# define an objective function to minimize
def my_fun(betas):
    x, y = getXY(betas)
    num_data = np.zeros((len(x), 2))
    num_data[:, 0] = x
    num_data[:, 1] = y
    # evaluate the difference between exp_data and num_data using curve length method
    return similarity_measures.curve_length_measure(exp_data, num_data)

# set up bounds for the optimization problem
bounds = np.ones((4, 2))*10.0
bounds[0, 0] = 0.0
bounds[1, 0] = -10.0
bounds[2, 0] = 10.0
bounds[3, 0] = 0.0

# USE DE from scipy to do the optimization
from scipy.optimize import differential_evolution

res = differential_evolution(my_fun, bounds=bounds)

print(res)

# Compute the resulting x y curve
x, y = getXY(res.x)

# plot the results
plt.figure()
plt.title('Result of optimization')
plt.plot(exp_data[:, 0], exp_data[:, 1], '.', label='Experimental data')
plt.plot(x, y, '-', label='Numerical model')
plt.grid(True)
plt.xlabel('Strain (mm/mm)', fontsize=16)
plt.ylabel('Stress (GPa)', fontsize=16)
plt.legend(fontsize=16)
plt.show()
